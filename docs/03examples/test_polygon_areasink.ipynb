# %% [markdown]
# # Test Polygon Area Sink

# %%
import matplotlib.pyplot as plt
import numpy as np

import timml as tml

# %%
ml = tml.ModelMaq(kaq=[1, 2], z=[10, 5, 4, 0], c=2)
xy = [(-50, 0), (50, 0), (50, 80), (-50, 80)]
p1 = tml.PolygonInhomMaq(
    ml,
    xy=xy,
    kaq=[1, 2],
    z=[10, 5, 4, 0],
    c=[2],
    topboundary="conf",
    N=0.01,
    order=5,
    ndeg=3,
)
rf = tml.Constant(ml, xr=0, yr=-1000, hr=2)
ml.solve()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 ml = tml.ModelMaq(kaq=[1, 2], z=[10, 5, 4, 0], c=2)
#       2 xy = [(-50, 0), (50, 0), (50, 80), (-50, 80)]
# ----> 3 p1 = tml.PolygonInhomMaq(ml, xy=xy,
#       4                      kaq=[1, 2], z=[10, 5, 4, 0], c=[2],
#       5                      topboundary='conf', N=0.01, order=5, ndeg=3)
#       6 rf = tml.Constant(ml, xr=0, yr=-1000, hr=2)
#       7 ml.solve()
#
# TypeError: __init__() got an unexpected keyword argument 'N'

# %%
ml.contour(win=[-100, 100, -100, 100], ngr=100, layers=[0], levels=20, labels=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ml.contour(win=[-100, 100, -100, 100], ngr=100, layers=[0], levels=20, labels=False)
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/util.py:119, in PlotTim.contour(self, win, ngr, layers, levels, layout, labels, decimals, color, newfig, figsize, legend)
#     117 xg = np.linspace(x1, x2, nx)
#     118 yg = np.linspace(y1, y2, ny)
# --> 119 h = self.headgrid(xg, yg, layers)
#     120 if newfig:
#     121     plt.figure(figsize=figsize)
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:170, in Model.headgrid(self, xg, yg, layers, printrow)
#     168         print('.', end='', flush=True)
#     169     for i in range(nx):
# --> 170         h[:, j, i] = self.head(xg[i], yg[j], layers)
#     171 if printrow:
#     172     print('', flush=True)
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:129, in Model.head(self, x, y, layers, aq)
#     118 """Head at `x`, `y`
#     119
#     120 Returns
#    (...)
#     125     or all layers of aquifer (otherwise)
#     126 """
#     128 if aq is None: aq = self.aq.find_aquifer_data(x, y)
# --> 129 rv = self.potential(x, y, aq) / aq.T
#     130 if layers is None:
#     131     return rv
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:84, in Model.potential(self, x, y, aq)
#      82 if aq is None: aq = self.aq.find_aquifer_data(x, y)
#      83 pot = np.zeros(aq.naq)
# ---> 84 for e in aq.elementlist:
#      85     pot += e.potential(x, y, aq)
#      86 rv = np.sum(pot * aq.eigvec, 1)
#
# AttributeError: 'Aquifer' object has no attribute 'elementlist'

# %%
x = np.linspace(-200, 200, 100)
h = ml.headalongline(x, 3)
plt.plot(x, h[0])
plt.plot(x, h[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 x = np.linspace(-200, 200, 100)
# ----> 2 h = ml.headalongline(x, 3)
#       3 plt.plot(x, h[0])
#       4 plt.plot(x, h[1])
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:231, in Model.headalongline(self, x, y, layers)
#     229 h = np.zeros((Nlayers, nx))
#     230 for i in range(nx):
# --> 231     h[:, i] = self.head(xg[i], yg[i], layers)
#     232 return h
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:129, in Model.head(self, x, y, layers, aq)
#     118 """Head at `x`, `y`
#     119
#     120 Returns
#    (...)
#     125     or all layers of aquifer (otherwise)
#     126 """
#     128 if aq is None: aq = self.aq.find_aquifer_data(x, y)
# --> 129 rv = self.potential(x, y, aq) / aq.T
#     130 if layers is None:
#     131     return rv
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:84, in Model.potential(self, x, y, aq)
#      82 if aq is None: aq = self.aq.find_aquifer_data(x, y)
#      83 pot = np.zeros(aq.naq)
# ---> 84 for e in aq.elementlist:
#      85     pot += e.potential(x, y, aq)
#      86 rv = np.sum(pot * aq.eigvec, 1)
#
# AttributeError: 'Aquifer' object has no attribute 'elementlist'

# %% [markdown]
# ## Checks for numerical derivative

# %%
# recharge inside polygon (should be 0.01)
x = 20
y = 60
d = 0.01
d2hdx2 = (ml.head(x + d, y) - 2 * ml.head(x, y) + ml.head(x - d, y)) / (d**2)
d2hdy2 = (ml.head(x, y + d) - 2 * ml.head(x, y) + ml.head(x, y - d)) / (d**2)
d2hdx2 + d2hdy2
aqin = ml.aq.inhomlist[0]
print("recharge from numerical derivative: ", np.sum(aqin.T * (d2hdx2 + d2hdy2)))
h = ml.head(x, y)
print("leakage from aq0 to aq1 from head difference: ", (h[1] - h[0]) / aqin.c[1])
print(
    "leakage from aq0 to aq1 from num. derivative: ",
    aqin.T[1] * (d2hdx2[1] + d2hdy2[1]),
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 y = 60
#       4 d = 0.01
# ----> 5 d2hdx2 = (ml.head(x + d, y) - 2 * ml.head(x, y) + ml.head(x - d, y)) / (d ** 2)
#       6 d2hdy2 = (ml.head(x, y + d) - 2 * ml.head(x, y) + ml.head(x, y - d)) / (d ** 2)
#       7 d2hdx2 + d2hdy2
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:129, in Model.head(self, x, y, layers, aq)
#     118 """Head at `x`, `y`
#     119
#     120 Returns
#    (...)
#     125     or all layers of aquifer (otherwise)
#     126 """
#     128 if aq is None: aq = self.aq.find_aquifer_data(x, y)
# --> 129 rv = self.potential(x, y, aq) / aq.T
#     130 if layers is None:
#     131     return rv
#
# File ~/anaconda3/lib/python3.8/site-packages/timml/model.py:84, in Model.potential(self, x, y, aq)
#      82 if aq is None: aq = self.aq.find_aquifer_data(x, y)
#      83 pot = np.zeros(aq.naq)
# ---> 84 for e in aq.elementlist:
#      85     pot += e.potential(x, y, aq)
#      86 rv = np.sum(pot * aq.eigvec, 1)
#
# AttributeError: 'Aquifer' object has no attribute 'elementlist'
