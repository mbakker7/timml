# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from timml import *

# %% [markdown]
# ### first test of `HeadLineSinkContainer`
# Still under development

# %%
ml = ModelMaq()
lsc = HeadLineSinkContainer(ml, xydict={0:[(0, 0), (10, 0), (10, 10)], 1:[(0, -5), (0, -10)]}, 
                            laydict={0: 0, 1: 0}, hls=10)
rf = Constant(ml, 0, -100, 20)
ml.solve()
# Out:
# Number of elements, Number of equations: 2 , 4
# ..
# solution complete

# %%
ml.contour([-20, 20, -20, 20], ngr=40)
