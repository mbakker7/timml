# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from timml import *

# %%
ml = ModelMaq()
lsc = HeadLineSinkContainer(ml, xydict={0:[(0, 0), (10, 0), (10, 10)], 1:[(0, -5), (0, -10)]}, 
                            laydict={0: 0, 1: 0}, hls=10)
rf = Constant(ml, 0, -100, 20)
ml.solve()
# Out:
# Number of elements, Number of equations: 2 , 4
# ..
# solution complete

# %%
ml.contour([-20, 20, -20, 20], ngr=40)

# %%
for ls in lsc.lslist:
    print(ls.layers)
# Out:
# [0]
# [0]
# [0]

# %%
for i in range(2):
    print(lsc.xls[i], lsc.yls[i])
    plt.plot(lsc.xls[i], lsc.yls[i])
# Out:
# [ 0 10 10] [ 0 10 10]
# [0 0] [0 0]

# %%
ml.initialize()
lsc.lslist
# Out:
# [HeadLineSink from (0.0, 0.0) to (10.0, 0.0),
#  HeadLineSink from (10.0, 0.0) to (10.0, 10.0),
#  HeadLineSink from (0.0, -5.0) to (0.0, -10.0)]

# %%
lsc.yls
# Out:
# [0, 10, 10, 0, 0]

# %%
lsc.plot()

# %%
lsc.xy
# Out:
# {0: [(0, 0), (10, 0), (10, 10)], 1: [(0, -5), (0, -10)]}

# %%
self = lsc
self.xls = [] # used for layout
self.yls = []
for key in self.xy.keys():
    xystring = np.atleast_1d(self.xy[key])
    self.xls.extend(xystring[:, 0])
    self.yls.extend(xystring[:, 0])

# %%
self.xls
# Out:
# [0, 10, 10, 0, 0]

# %%
xystring[:, 0]
# Out:
# array([0, 0])

# %%
a = []

# %%
a.append(xystring[:, 0])
a
# Out:
# [array([0, 0])]
