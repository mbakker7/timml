# %%
import timml as tml
import numpy as np
import matplotlib.pyplot as plt

# %%
ml = tml.ModelMaq(kaq=[1, 2], z=[10, 5, 4, 0], c=20)
xy = [(-5,0), (5,0), (5,8), (-5,8)]
p1 = tml.PolygonInhomMaq(ml, xy=[(-5,0), (5,0), (5,8), (-5,8)], 
                         kaq=[0.2, 8], z=[11,10,5,4,0], c=[2, 20], 
                         topboundary='semi', hstar=1.0, order=3, ndeg=1)
w = tml.Well(ml, xw=0, yw=-10, Qw=100, layers=1)
rf = tml.Constant(ml, xr=0, yr=-100, hr=2)
ml.solve()
# Out:
# Number of elements, Number of equations: 11 , 65
# ...........
# solution complete

# %%
ml.contour([-10, 10, -10, 10], 50, [0, 1], 20)
# Out:
# [<matplotlib.contour.QuadContourSet at 0x7f9a3f2c6850>,
#  <matplotlib.contour.QuadContourSet at 0x7f9a3f30d4f0>]
